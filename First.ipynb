# %% [markdown]
# <a href="https://colab.research.google.com/github/JY1Lnz/cuda_learn/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
print('add')
